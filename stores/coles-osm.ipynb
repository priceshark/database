# %%
import json

osm = json.load(open("coles-osm-raw.json"))["elements"]
raw = []
for line in open("coles-raw.jsonl"):
    raw.append(json.loads(line))

manual = {}
for x in osm:
    w = x["tags"].get("website")
    if w is None:
        continue
    if not w.startswith("https://www.coles.com.au/find-stores/coles/"):
        continue
    store = int(w.split("-")[-1])
    manual[store] = x["id"]

# %%
from math import sqrt

matched = {}

for x in raw:
    store = int(x["storeId"])
    if store in manual:
        continue
    
    lat_a = x["latitude"]
    lon_a = x["longitude"]
    name = x["storeName"]

    if store == 4947:
        continue

    for y in osm:
        if y["type"] == "node":
            lat_b = y["lat"]
            lon_b = y["lon"]
        else:
            lat_b = y["center"]["lat"]
            lon_b = y["center"]["lon"]

        
        distance = sqrt((lat_a-lat_b)**2+(lon_a-lon_b)**2)
        if distance < 0.002:
            if store in matched:
                print("Duplicate:", store, name, "=>", matched[store], y["id"])
                print(f"    https://www.openstreetmap.org/search?query={lat_a}%20{lon_a}")
                print(f"    https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{{{bbox}}}});out%20geom;&C={lat_a}%3B{lon_a}%3B16&R=")
                # print(f"    https://www.openstreetmap.org/{y['type']}/{y['id']}")
            else:
                # print(x["storeName"], y["tags"])
                matched[store] = y["id"]

# %%
seen = []
for k, v in matched.items():
    if v in seen:
        print("Duplicate:", k)
    seen.append(v)

# %%
total = len(matched) + len(manual)

print("Loaded from OSM:", len(osm))
print("Loaded from Coles:", len(raw))
print("Matched:", total)
print("    Manually:", len(manual))
print("    Automatically:", len(matched))
print()

missing = len(raw) - total
print(f"Missing: {missing} ({missing/len(raw)*100}%)")
# Out:
# Loaded from OSM: 792
# Loaded from Coles: 851
# Matched: 733
#     Manually: 43
#     Automatically: 690
#
# Missing: 118 (13.866039952996475%)

# %%
matched |= manual
matched = dict(sorted(matched.items()))

json.dump(matched, open("coles-osm.json","w"), indent=2)

# %%
for x in raw:
    store = int(x["storeId"])
    if store in matched:
        continue
    lat = x["latitude"]
    lon = x["longitude"]
    name = x["storeName"]

    print(name, store)
    print(f"    https://www.openstreetmap.org/search?query={lat}%20{lon}")
    print(f"    https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{{{bbox}}}});out%20geom;&C={lat}%3B{lon}%3B16&R=")
    print()
# Out:
# Coles Tuggeranong 911
#     https://www.openstreetmap.org/search?query=-35.416908%20149.065036
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-35.416908%3B149.065036%3B16&R=
#
# Coles Bankstown 7662
#     https://www.openstreetmap.org/search?query=-33.916409%20151.037318
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.916409%3B151.037318%3B16&R=
#
# Coles Banora Central 4577
#     https://www.openstreetmap.org/search?query=-28.213609%20153.521894
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.213609%3B153.521894%3B16&R=
#
# Coles Berkeley 4387
#     https://www.openstreetmap.org/search?query=-34.480423%20150.845859
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.480423%3B150.845859%3B16&R=
#
# Coles Blacktown 862
#     https://www.openstreetmap.org/search?query=-33.770246%20150.904651
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.770246%3B150.904651%3B16&R=
#
# Coles Huntlee 7702
#     https://www.openstreetmap.org/search?query=-32.67221%20151.34969
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.67221%3B151.34969%3B16&R=
#
# Coles Budgewoi 5759
#     https://www.openstreetmap.org/search?query=-33.233581%20151.554132
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.921647%3B138.634717%3B16&R=
#
# Coles Armstrong Creek 7501
#     https://www.openstreetmap.org/search?query=-38.229281%20144.33682
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.229281%3B144.33682%3B16&R=
#
# Coles Chadstone Village 7574
#     https://www.openstreetmap.org/search?query=-37.879799%20145.091457
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.879799%3B145.091457%3B16&R=
#
# Coles Botanic Ridge 7733
#     https://www.openstreetmap.org/search?query=-38.148154%20145.285791
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.148154%3B145.285791%3B16&R=
#
# Coles Chadstone 643
#     https://www.openstreetmap.org/search?query=-37.886249%20145.082538
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.886249%3B145.082538%3B16&R=
#
# Coles Craigieburn 7611
#     https://www.openstreetmap.org/search?query=-37.594489%20144.913435
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.594489%3B144.913435%3B16&R=
#
# Coles Craigieburn Village 7669
#     https://www.openstreetmap.org/search?query=-37.573384%20144.899746
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.573384%3B144.899746%3B16&R=
#
# Coles Cranbourne 7918
#     https://www.openstreetmap.org/search?query=-38.109489%20145.281794
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.109489%3B145.281794%3B16&R=
#
# Coles The Pines 524
#     https://www.openstreetmap.org/search?query=-37.762709%20145.16767
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.762709%3B145.16767%3B16&R=
#
# Coles Epping 654
#     https://www.openstreetmap.org/search?query=-37.652761%20145.020298
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.652761%3B145.020298%3B16&R=
#
# Coles Hoppers Crossing 7718
#     https://www.openstreetmap.org/search?query=-37.881655%20144.70061
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.881655%3B144.70061%3B16&R=
#
# Coles Kangaroo Flat 7618
#     https://www.openstreetmap.org/search?query=-36.810106%20144.240595
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-36.810106%3B144.240595%3B16&R=
#
# Coles Highpoint 7664
#     https://www.openstreetmap.org/search?query=-37.773468%20144.88865
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.773468%3B144.88865%3B16&R=
#
# Coles Fountain Gate 8786
#     https://www.openstreetmap.org/search?query=-38.017772%20145.303724
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.017772%3B145.303724%3B16&R=
#
# Coles Port Melbourne 646
#     https://www.openstreetmap.org/search?query=-37.838665%20144.941366
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.838665%3B144.941366%3B16&R=
#
# Coles Sale 679
#     https://www.openstreetmap.org/search?query=-38.107203%20147.062334
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.107203%3B147.062334%3B16&R=
#
# Coles Local South Melbourne - Normanby Road 7682
#     https://www.openstreetmap.org/search?query=-37.831232%20144.945005
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.831232%3B144.945005%3B16&R=
#
# Coles Local Surrey Hills 7802
#     https://www.openstreetmap.org/search?query=-37.824023%20145.097208
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.824023%3B145.097208%3B16&R=
#
# Coles Tarneit Central 5802
#     https://www.openstreetmap.org/search?query=-37.835108%20144.691704
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.835108%3B144.691704%3B16&R=
#
# Coles Local Toorak Village 7670
#     https://www.openstreetmap.org/search?query=-37.84098%20145.0095
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.84098%3B145.0095%3B16&R=
#
# Coles Knox 650
#     https://www.openstreetmap.org/search?query=-37.868333%20145.238146
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.868333%3B145.238146%3B16&R=
#
# Coles Northpoint 596
#     https://www.openstreetmap.org/search?query=-38.368649%20142.49452
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.368649%3B142.49452%3B16&R=
#
# Coles Waurn Ponds 7810
#     https://www.openstreetmap.org/search?query=-38.199304%20144.318893
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-38.199304%3B144.318893%3B16&R=
#
# Coles Birallee Park 658
#     https://www.openstreetmap.org/search?query=-36.128426%20146.864416
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-36.128426%3B146.864416%3B16&R=
#
# Coles Alexander Heights 365
#     https://www.openstreetmap.org/search?query=-31.830133%20115.852756
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.830133%3B115.852756%3B16&R=
#
# Coles Trinity Village 4815
#     https://www.openstreetmap.org/search?query=-31.6279%20115.69168
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.6279%3B115.69168%3B16&R=
#
# Coles Banksia Grove 260
#     https://www.openstreetmap.org/search?query=-31.70578%20115.80114
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.70578%3B115.80114%3B16&R=
#
# Coles Bassendean 395
#     https://www.openstreetmap.org/search?query=-31.903358%20115.952885
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.903358%3B115.952885%3B16&R=
#
# Coles Beechboro 363
#     https://www.openstreetmap.org/search?query=-31.876428%20115.925114
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.876428%3B115.925114%3B16&R=
#
# Coles Beeliar 494
#     https://www.openstreetmap.org/search?query=-32.12802%20115.79784
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.12802%3B115.79784%3B16&R=
#
# Coles Byford 263
#     https://www.openstreetmap.org/search?query=-32.220426%20116.006227
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.220426%3B116.006227%3B16&R=
#
# Coles Carousel 322
#     https://www.openstreetmap.org/search?query=-32.018861%20115.935902
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.018861%3B115.935902%3B16&R=
#
# Coles Kwinana 488
#     https://www.openstreetmap.org/search?query=-32.245302%20115.8138
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.245302%3B115.8138%3B16&R=
#
# Coles Caversham 262
#     https://www.openstreetmap.org/search?query=-31.867661%20115.96723
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.867661%3B115.96723%3B16&R=
#
# Coles Currambine 7542
#     https://www.openstreetmap.org/search?query=-31.726089%20115.744934
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.726089%3B115.744934%3B16&R=
#
# Coles Ellenbrook 485
#     https://www.openstreetmap.org/search?query=-31.782793%20115.968267
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.782793%3B115.968267%3B16&R=
#
# Coles Erskine 348
#     https://www.openstreetmap.org/search?query=-32.560682%20115.688256
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.560682%3B115.688256%3B16&R=
#
# Coles Greenwood 303
#     https://www.openstreetmap.org/search?query=-31.83122%20115.802572
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.83122%3B115.802572%3B16&R=
#
# Coles Innaloo Westfield 298
#     https://www.openstreetmap.org/search?query=-31.901491%20115.79776
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.901491%3B115.79776%3B16&R=
#
# Coles Karrinyup 205
#     https://www.openstreetmap.org/search?query=-31.875854%20115.780277
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.875854%3B115.780277%3B16&R=
#
# Coles Meadow Springs 362
#     https://www.openstreetmap.org/search?query=-32.493561%20115.746963
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.493561%3B115.746963%3B16&R=
#
# Coles Noranda Square 344
#     https://www.openstreetmap.org/search?query=-31.876106%20115.895472
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.876106%3B115.895472%3B16&R=
#
# Coles Secret Harbour 4790
#     https://www.openstreetmap.org/search?query=-32.407243%20115.757598
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.407243%3B115.757598%3B16&R=
#
# Coles Swan View 398
#     https://www.openstreetmap.org/search?query=-31.888515%20116.046839
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.888515%3B116.046839%3B16&R=
#
# Coles Yanchep 7680
#     https://www.openstreetmap.org/search?query=-31.550191%20115.639431
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.550191%3B115.639431%3B16&R=
