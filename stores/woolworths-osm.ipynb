# %%
import json

osm = json.load(open("woolworths-osm-raw.json"))["elements"]
raw = []
for line in open("woolworths-raw.jsonl"):
    raw.append(json.loads(line))

manual = {}
for x in osm:
    w = x["tags"].get("website")
    if w is None:
        continue
    if not w.startswith("https://www.woolworths.com.au/shop/storelocator/"):
        continue
    store = int(w.split("-")[-1])
    manual[store] = x["id"]

# %%
from math import sqrt

matched = {}

for x in raw:
    store = int(x["no"])
    if store in manual:
        continue
    
    lat_a = float(x["latitude"])
    lon_a = float(x["longtitude"]) # upstream typo :)
    name = x["name"]

    for y in osm:
        if y["type"] == "node":
            lat_b = y["lat"]
            lon_b = y["lon"]
        else:
            lat_b = (y["bounds"]["minlat"] + y["bounds"]["maxlat"]) / 2
            lon_b = (y["bounds"]["minlon"] + y["bounds"]["maxlon"]) / 2

        
        distance = sqrt((lat_a-lat_b)**2+(lon_a-lon_b)**2)
        if distance < 0.001:
            if store in matched:
                print("Duplicate:", store, name, "=>", matched[store], y["id"])
                print(f"    https://www.openstreetmap.org/search?query={lat_a}%20{lon_a}")
                print(f"    https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{{{bbox}}}});out%20geom;&C={lat_a}%3B{lon_a}%3B16&R=")
                # print(f"    https://www.openstreetmap.org/{y['type']}/{y['id']}")
            else:
                # print(x["storeName"], y["tags"])
                matched[store] = y["id"]
# Out:
# Duplicate: 2657 Taigum => 25505345 1239527310
#     https://www.openstreetmap.org/search?query=-27.35135465%20153.04876207
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.35135465%3B153.04876207%3B16&R=

# %%
seen = []
for k, v in matched.items():
    if v in seen:
        print("Duplicate:", k, v)
    seen.append(v)
# Out:
# Duplicate: 2696 290081135

# %%
total = len(matched) + len(manual)

print("Loaded from OSM:", len(osm))
print("Loaded from raw:", len(raw))
print("Matched:", total)
print("    Manually:", len(manual))
print("    Automatically:", len(matched))
print()

missing = len(raw) - total
print(f"Missing: {missing} ({missing/len(raw)*100}%)")
# Out:
# Loaded from OSM: 977
# Loaded from raw: 1113
# Matched: 919
#     Manually: 26
#     Automatically: 893
#
# Missing: 194 (17.4303683737646%)

# %%
matched |= manual
matched = dict(sorted(matched.items()))

json.dump(matched, open("woolworths-osm.json","w"), indent=2)

# %%
for x in raw:
    store = int(x["no"])
    if store in matched:
        continue
    lat = x["latitude"]
    lon = x["longtitude"]
    name = x["name"]

    print(name, store)
    print(f"    https://www.openstreetmap.org/search?query={lat}%20{lon}")
    print(f"    https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{{{bbox}}}});out%20geom;&C={lat}%3B{lon}%3B16&R=")
    print()
# Out:
# Spotswood 3391
#     https://www.openstreetmap.org/search?query=-37.830928%20144.881557
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.830928%3B144.881557%3B16&R=
#
# Union Rd 3576
#     https://www.openstreetmap.org/search?query=-37.77299%20144.91573
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.77299%3B144.91573%3B16&R=
#
# Ascot Vale 3094
#     https://www.openstreetmap.org/search?query=-37.7758%20144.92836
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.7758%3B144.92836%3B16&R=
#
# Gadsden 8285
#     https://www.openstreetmap.org/search?query=-37.80689%20144.94292
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.80689%3B144.94292%3B16&R=
#
# City North 8281
#     https://www.openstreetmap.org/search?query=-37.80307%20144.95756
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-37.80307%3B144.95756%3B16&R=
#
# Queens Place 3028
#     https://www.openstreetmap.org/search?query=-37.81002227%20144.95866811
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.373992%3B150.896949%3B16&R=
#
# Cecil Hills 1306
#     https://www.openstreetmap.org/search?query=-33.88684546%20150.8487645
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.88684546%3B150.8487645%3B16&R=
#
# Bonnyrigg 1184
#     https://www.openstreetmap.org/search?query=-33.8860282%20150.8885955
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.8860282%3B150.8885955%3B16&R=
#
# Delroy Park 1304
#     https://www.openstreetmap.org/search?query=-32.25331064%20148.5774067
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.25331064%3B148.5774067%3B16&R=
#
# Sylvania 1615
#     https://www.openstreetmap.org/search?query=-34.0106583%20151.1033895
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.0106583%3B151.1033895%3B16&R=
#
# Caringbah CFC 8882
#     https://www.openstreetmap.org/search?query=-34.03626%20151.13247
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.03626%3B151.13247%3B16&R=
#
# Dubbo 1121
#     https://www.openstreetmap.org/search?query=-32.254425%20148.632113
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.254425%3B148.632113%3B16&R=
#
# Woolooware Bay 1600
#     https://www.openstreetmap.org/search?query=-34.0388144%20151.1427003
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-34.0388144%3B151.1427003%3B16&R=
#
# Greystanes 1958
#     https://www.openstreetmap.org/search?query=-33.82870559%20150.95154657
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.82870559%3B150.95154657%3B16&R=
#
# Roselands 1409
#     https://www.openstreetmap.org/search?query=-33.9355139%20151.0685119
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.9355139%3B151.0685119%3B16&R=
#
# Blacktown 1288
#     https://www.openstreetmap.org/search?query=-33.77145931%20150.9059675
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.77145931%3B150.9059675%3B16&R=
#
# Berala 1251
#     https://www.openstreetmap.org/search?query=-33.87147596%20151.03221736
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.87147596%3B151.03221736%3B16&R=
#
# Toongabbie 1413
#     https://www.openstreetmap.org/search?query=-33.78731526%20150.9493058
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.78731526%3B150.9493058%3B16&R=
#
# Bexley North (Metro) 1370
#     https://www.openstreetmap.org/search?query=-33.93898965%20151.1149231
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.93898965%3B151.1149231%3B16&R=
#
# Cowper St Metro 1611
#     https://www.openstreetmap.org/search?query=-33.832062%20151.012863
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.832062%3B151.012863%3B16&R=
#
# Rockdale 1252
#     https://www.openstreetmap.org/search?query=-33.9582086%20151.1401211
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.9582086%3B151.1401211%3B16&R=
#
# George St Parramatta 8963
#     https://www.openstreetmap.org/search?query=-33.81498533%20151.0099986
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.81498533%3B151.0099986%3B16&R=
#
# Lidcombe 1598
#     https://www.openstreetmap.org/search?query=-33.84857934%20151.0488485
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.84857934%3B151.0488485%3B16&R=
#
# Carter St Metro 8485
#     https://www.openstreetmap.org/search?query=-33.85141%20151.06165
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.85141%3B151.06165%3B16&R=
#
# Norwest 1662
#     https://www.openstreetmap.org/search?query=-33.736183%20150.950775
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.736183%3B150.950775%3B16&R=
#
# Kellyville Grove 1659
#     https://www.openstreetmap.org/search?query=-33.718592%20150.954105
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.718592%3B150.954105%3B16&R=
#
# Rhodes 1176
#     https://www.openstreetmap.org/search?query=-33.8299553%20151.0856931
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.8299553%3B151.0856931%3B16&R=
#
# Knightsbridge 1009
#     https://www.openstreetmap.org/search?query=-33.71299%20150.99422
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.71299%3B150.99422%3B16&R=
#
# Eastlakes Metro 8274
#     https://www.openstreetmap.org/search?query=-33.92467%20151.21032
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.92467%3B151.21032%3B16&R=
#
# Eastwood 1200
#     https://www.openstreetmap.org/search?query=-33.79234014%20151.08135
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.273718%3B149.276481%3B16&R=
#
# East Newcastle 1483
#     https://www.openstreetmap.org/search?query=-32.92712%20151.77929
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.92712%3B151.77929%3B16&R=
#
# Whyalla Westlands 5635
#     https://www.openstreetmap.org/search?query=-33.026803%20137.53115
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.026803%3B137.53115%3B16&R=
#
# Raymond Terrace North (MarketPlace) 1245
#     https://www.openstreetmap.org/search?query=-32.75985%20151.744329
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.75985%3B151.744329%3B16&R=
#
# Forster 1177
#     https://www.openstreetmap.org/search?query=-32.20190099%20152.518677
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.20190099%3B152.518677%3B16&R=
#
# Taree 1205
#     https://www.openstreetmap.org/search?query=-31.911251%20152.459589
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.911251%3B152.459589%3B16&R=
#
# Moree 1335
#     https://www.openstreetmap.org/search?query=-29.467281%20149.841515
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-29.467281%3B149.841515%3B16&R=
#
# Nambucca Heads 1311
#     https://www.openstreetmap.org/search?query=-30.643395%20153.003512
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-30.643395%3B153.003512%3B16&R=
#
# Woolgoolga 1327
#     https://www.openstreetmap.org/search?query=-30.11264002%20153.1903448
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-30.11264002%3B153.1903448%3B16&R=
#
# Casino 2540
#     https://www.openstreetmap.org/search?query=-28.86374199%20153.0495
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.86374199%3B153.0495%3B16&R=
#
# Toowoomba Drayton 2173
#     https://www.openstreetmap.org/search?query=-27.60191293%20151.9142477
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.60191293%3B151.9142477%3B16&R=
#
# Toowoomba Grand Central 2797
#     https://www.openstreetmap.org/search?query=-27.561073%20151.951455
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.561073%3B151.951455%3B16&R=
#
# Tweed City 2652
#     https://www.openstreetmap.org/search?query=-28.2006262%20153.5450324
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.2006262%3B153.5450324%3B16&R=
#
# Reedy Creek 2945
#     https://www.openstreetmap.org/search?query=-28.10654186%20153.40508623
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.10654186%3B153.40508623%3B16&R=
#
# Robina North 2534
#     https://www.openstreetmap.org/search?query=-28.0762103%20153.3867329
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.0762103%3B153.3867329%3B16&R=
#
# Burleigh Heads North (Metro) 2480
#     https://www.openstreetmap.org/search?query=-28.08987672%20153.4504551
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.08987672%3B153.4504551%3B16&R=
#
# Carrara 2887
#     https://www.openstreetmap.org/search?query=-28.029372%20153.388333
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.029372%3B153.388333%3B16&R=
#
# Mermaid Plaza 8381
#     https://www.openstreetmap.org/search?query=-28.04989%20153.43574
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.04989%3B153.43574%3B16&R=
#
# Pacific Fair 2078
#     https://www.openstreetmap.org/search?query=-28.0365109%20153.427803
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-28.0365109%3B153.427803%3B16&R=
#
# Broadwater 2503
#     https://www.openstreetmap.org/search?query=-27.975869%20153.419254
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.975869%3B153.419254%3B16&R=
#
# Australia Fair (Southport) 2577
#     https://www.openstreetmap.org/search?query=-27.96878%20153.416817
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.96878%3B153.416817%3B16&R=
#
# Brookwater 2864
#     https://www.openstreetmap.org/search?query=-27.66348466%20152.8913727
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.66348466%3B152.8913727%3B16&R=
#
# Hope Island 2506
#     https://www.openstreetmap.org/search?query=-27.87799577%20153.364927
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.87799577%3B153.364927%3B16&R=
#
# Fernvale 2715
#     https://www.openstreetmap.org/search?query=-27.45828055%20152.6545214
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.45828055%3B152.6545214%3B16&R=
#
# Browns Plains Westpoint 2656
#     https://www.openstreetmap.org/search?query=-27.659774%20153.039637
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.659774%3B153.039637%3B16&R=
#
# Loganholme 2300
#     https://www.openstreetmap.org/search?query=-27.660711%20153.172699
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.660711%3B153.172699%3B16&R=
#
# Yeerongpilly 2693
#     https://www.openstreetmap.org/search?query=-27.5243%20153.01229
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.5243%3B153.01229%3B16&R=
#
# Mountain View (Mt Gravatt Plaza) 2616
#     https://www.openstreetmap.org/search?query=-27.539113%20153.081045
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.539113%3B153.081045%3B16&R=
#
# Rochedale CFC 2755
#     https://www.openstreetmap.org/search?query=-27.54879%20153.1185
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.54879%3B153.1185%3B16&R=
#
# Southpoint Metro 2042
#     https://www.openstreetmap.org/search?query=-27.48216875%20153.0236444
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.48216875%3B153.0236444%3B16&R=
#
# Fish Lane 2241
#     https://www.openstreetmap.org/search?query=-27.47423%20153.018066
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.47423%3B153.018066%3B16&R=
#
# Tank St (Metro) 2338
#     https://www.openstreetmap.org/search?query=-27.468075%20153.020381
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.468075%3B153.020381%3B16&R=
#
# Ann St Metro 2754
#     https://www.openstreetmap.org/search?query=-27.466534%20153.02606
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.466534%3B153.02606%3B16&R=
#
# Kelvin Grove 2718
#     https://www.openstreetmap.org/search?query=-27.453562%20153.014309
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.453562%3B153.014309%3B16&R=
#
# Redland Bay 2714
#     https://www.openstreetmap.org/search?query=-27.6114%20153.30213
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.6114%3B153.30213%3B16&R=
#
# Fortitude Valley 2885
#     https://www.openstreetmap.org/search?query=-27.45671%20153.03234
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.45671%3B153.03234%3B16&R=
#
# Teneriffe Metro 2719
#     https://www.openstreetmap.org/search?query=-27.45409%20153.047318
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.45409%3B153.047318%3B16&R=
#
# Belmont 2028
#     https://www.openstreetmap.org/search?query=-27.48408%20153.12615
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.48408%3B153.12615%3B16&R=
#
# Hamilton Harbour (Metro) 2115
#     https://www.openstreetmap.org/search?query=-27.43897758%20153.0669353
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.43897758%3B153.0669353%3B16&R=
#
# Rode Road 8369
#     https://www.openstreetmap.org/search?query=-27.39305%20153.01116
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.39305%3B153.01116%3B16&R=
#
# Margate 2690
#     https://www.openstreetmap.org/search?query=-27.2445668%20153.1079568
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.2445668%3B153.1079568%3B16&R=
#
# Bellmere 2015
#     https://www.openstreetmap.org/search?query=-27.0901%20152.9264
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.0901%3B152.9264%3B16&R=
#
# Woodford 2052
#     https://www.openstreetmap.org/search?query=-26.952631%20152.777476
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-26.952631%3B152.777476%3B16&R=
#
# Banksia Beach 2308
#     https://www.openstreetmap.org/search?query=-27.0443128%20153.1369519
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-27.0443128%3B153.1369519%3B16&R=
#
# Gympie Southside 2522
#     https://www.openstreetmap.org/search?query=-26.199923%20152.648899
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-26.199923%3B152.648899%3B16&R=
#
# Cooloola 2726
#     https://www.openstreetmap.org/search?query=-25.970312%20152.986989
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-25.970312%3B152.986989%3B16&R=
#
# Biloela 2569
#     https://www.openstreetmap.org/search?query=-24.401923%20150.513297
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-24.401923%3B150.513297%3B16&R=
#
# Kepnock 2050
#     https://www.openstreetmap.org/search?query=-24.86985%20152.3805
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-24.86985%3B152.3805%3B16&R=
#
# Bargara 2519
#     https://www.openstreetmap.org/search?query=-24.819056%20152.4554
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-24.819056%3B152.4554%3B16&R=
#
# Boyne Island 2580
#     https://www.openstreetmap.org/search?query=-23.94733799%20151.354057
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-23.94733799%3B151.354057%3B16&R=
#
# North Rockhampton 2587
#     https://www.openstreetmap.org/search?query=-23.354121%20150.521531
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-23.354121%3B150.521531%3B16&R=
#
# Marian 2140
#     https://www.openstreetmap.org/search?query=-21.14691871%20148.9517903
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-21.14691871%3B148.9517903%3B16&R=
#
# Walkerston 2553
#     https://www.openstreetmap.org/search?query=-21.16094652%20149.0651753
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-21.16094652%3B149.0651753%3B16&R=
#
# Ooralea 2939
#     https://www.openstreetmap.org/search?query=-21.1750965%20149.1512756
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-21.1750965%3B149.1512756%3B16&R=
#
# Andergrove 2709
#     https://www.openstreetmap.org/search?query=-21.097053%20149.18534
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-21.097053%3B149.18534%3B16&R=
#
# Rural View Mackay 2853
#     https://www.openstreetmap.org/search?query=-21.0656757%20149.1607818
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-21.0656757%3B149.1607818%3B16&R=
#
# Riverway Plaza 2623
#     https://www.openstreetmap.org/search?query=-19.363095%20146.730974
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-19.363095%3B146.730974%3B16&R=
#
# Willows 2234
#     https://www.openstreetmap.org/search?query=-19.3155774%20146.7260178
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-19.3155774%3B146.7260178%3B16&R=
#
# Kirwan 2501
#     https://www.openstreetmap.org/search?query=-19.3037194%20146.7417336
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-19.3037194%3B146.7417336%3B16&R=
#
# Vincent 2340
#     https://www.openstreetmap.org/search?query=-19.287226%20146.761883
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-19.287226%3B146.761883%3B16&R=
#
# North Shore Townsville 2785
#     https://www.openstreetmap.org/search?query=-19.25341812%20146.6999554
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-19.25341812%3B146.6999554%3B16&R=
#
# Ingham 2723
#     https://www.openstreetmap.org/search?query=-18.64879928%20146.1619178
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-18.64879928%3B146.1619178%3B16&R=
#
# Gordonvale 2642
#     https://www.openstreetmap.org/search?query=-17.0872859%20145.7741699
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-17.0872859%3B145.7741699%3B16&R=
#
# Cairns Central 2669
#     https://www.openstreetmap.org/search?query=-16.9263021%20145.7733055
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-16.9263021%3B145.7733055%3B16&R=
#
# Dalyellup 4418
#     https://www.openstreetmap.org/search?query=-33.398093%20115.6345279
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-33.398093%3B115.6345279%3B16&R=
#
# Byford Town 4813
#     https://www.openstreetmap.org/search?query=-32.221936%20116.004538
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.221936%3B116.004538%3B16&R=
#
# Mandurah Greenfields 4395
#     https://www.openstreetmap.org/search?query=-32.52099843%20115.75207943
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.52099843%3B115.75207943%3B16&R=
#
# Baldivis 4308
#     https://www.openstreetmap.org/search?query=-32.33350759%20115.8161347
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.33350759%3B115.8161347%3B16&R=
#
# Singleton 4782
#     https://www.openstreetmap.org/search?query=-32.44764458%20115.7641275
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.44764458%3B115.7641275%3B16&R=
#
# Midland Centrepoint 4369
#     https://www.openstreetmap.org/search?query=-31.89076709%20116.0021226
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-31.89076709%3B116.0021226%3B16&R=
#
# Wellard 4604
#     https://www.openstreetmap.org/search?query=-32.2631121%20115.81633122
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=-32.2631121%3B115.81633122%3B16&R=
#
# Kwinana 4335
#     https://www.openstreetmap.org/search?query=-32.24646514%20115.8153325
#     https://overpass-turbo.eu/?Q=nwr['shop'='supermarket']({{bbox}});out%20geom;&C=